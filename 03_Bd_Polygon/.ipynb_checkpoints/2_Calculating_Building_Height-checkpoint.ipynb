# %% [markdown]
# # Calculate Building Height

# %%
import geopandas as gpd
from shapely.geometry import box
import pandas as pd
import rasterio 
from rasterstats import zonal_stats
import numpy as np
import os
import glob
import time

### Configuration ###
NDSM = "/storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/atlanta_DSM_sample.tif"
BD_PATH = "/storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/atlanta_building.geojson"
INT_DIR = "/storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate"
OUTPUT_PATH = "/storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/building_ft_height.geojson"
### ------------- ###

# %% [markdown]
# # Helper functions

# %%
def compute_height(
    gdf_path: str,
    ndsm_path: str,
    output_dir: str,
    output_path: str,
    chunk_size: int = 500,
) -> None:
    """
    Compute building height per feature by chunking a GeoDataFrame,
    computing zonal stats on the NDSM raster, and saving both chunked
    outputs and a merged final GeoJSON.

    Parameters
    ----------
    gdf_path : str
        Path to the input vector file (any format supported by GeoPandas).
    ndsm_path : str
        Path to the normalized DSM raster used for zonal stats.
    output_dir : str
        Directory where part files will be saved.
    output_path : str
        Path where final output will be saved.
    chunk_size : int, optional
        Number of features per chunk (default is 500).
    """
    # ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # load and subset only needed columns
    gdf = gpd.read_file(gdf_path)

    # Load raster CRS using rasterio
    with rasterio.open(ndsm_path) as ndsm_src:
        ndsm_crs = ndsm_src.crs

    if gdf.crs != ndsm_crs:
        print(f"Reprojecting vector data from {gdf.crs} to {ndsm_crs}")
        gdf = gdf.to_crs(ndsm_crs)

    # split into chunks
    chunks = [gdf.iloc[i : i+chunk_size] 
              for i in range(0, len(gdf), chunk_size)]

    part_paths = []
    for idx, chunk in enumerate(chunks, start=1):
        # compute stats for this chunk only
        stats = zonal_stats(
            chunk, ndsm_path,
            stats=["mean", "std", "max"],
            geojson_out=True
        )

        # build a DataFrame of stats
        stats_df = pd.DataFrame([feat["properties"] for feat in stats])
        stats_df["std"] = stats_df["std"].fillna(0).round(2)
        stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
        stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
        stats_df["coef_var"] = stats_df["std"] / stats_df["mean_h"]

        # reset indices so they align
        chunk_reset = chunk.reset_index(drop=True)
        stats_reset = stats_df.reset_index(drop=True)

        # join and compute final fields
        result = chunk_reset.join(stats_reset[["coef_var", "mean_h", "max_h"]])
        result["bd_h"] = np.where(
            result["coef_var"] >= 0.7,
            result["mean_h"],
            result["max_h"]
        )
        # save this chunk
        part_path = os.path.join(
            output_dir,
            f"part_{idx:03d}.geojson"
        )
        result.to_file(part_path, driver="GeoJSON")
        part_paths.append(part_path)
        print(f"Saved chunk {idx} to {part_path}")

    # merge all parts
    merged = gpd.GeoDataFrame(pd.concat(
        [gpd.read_file(p) for p in sorted(part_paths)],
        ignore_index=True
    ))
    merged.to_file(output_path, driver="GeoJSON")
    print(f"Merged output saved to {output_path}")

# %% [markdown]
# # Run it

# %%
if __name__ == "__main__":
    s_time = time.time()
    
    compute_height(
        gdf_path=BD_PATH,
        ndsm_path=NDSM,
        output_dir=INT_DIR,
        output_path=OUTPUT_PATH,
        chunk_size=500,                      # tweak as needed
    )
    f_time = time.time()
    p_time = f_time - s_time
    print(f"Processing time: {p_time:.2f} seconds")
# Out:
# Reprojecting vector data from EPSG:4326 to EPSG:6446
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 1 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_001.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 2 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_002.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 3 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_003.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 4 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_004.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 5 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_005.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 6 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_006.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 7 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_007.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 8 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_008.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 9 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_009.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 10 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_010.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 11 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_011.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 12 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_012.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 13 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_013.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 14 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_014.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 15 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_015.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 16 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_016.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 17 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_017.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 18 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_018.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 19 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_019.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 20 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_020.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 21 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_021.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 22 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_022.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 23 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_023.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 24 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_024.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 25 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_025.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 26 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_026.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 27 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_027.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 28 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_028.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 29 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_029.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 30 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_030.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 31 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_031.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 32 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_032.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 33 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_033.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 34 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_034.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 35 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_035.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 36 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_036.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 37 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_037.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 38 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_038.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 39 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_039.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 40 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_040.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# ...
# Saved chunk 585 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_585.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 586 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_586.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 587 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_587.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 588 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_588.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 589 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_589.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 590 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_590.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 591 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_591.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 592 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_592.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 593 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_593.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 594 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_594.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 595 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_595.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 596 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_596.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 597 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_597.geojson
# /tmp/ipykernel_2873057/1904585042.py:55: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["std"] = stats_df["std"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["mean_h"] = stats_df["mean"].fillna(0).round(2)
# /tmp/ipykernel_2873057/1904585042.py:57: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stats_df["max_h"] = stats_df["max"].fillna(0).round(2)
# Saved chunk 598 to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/Intermediate/part_598.geojson
# /tmp/ipykernel_2873057/1904585042.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = gpd.GeoDataFrame(pd.concat(
# Merged output saved to /storage/project/r-rbasu31-0/hyu483/Test_UMEP/Nm/building_ft_height.geojson
# Processing time: 619.83 seconds
